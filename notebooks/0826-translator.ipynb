# %%
# %reload_ext autoreload
# %autoreload 2

# %%
# %cd ..
# Out:
# c:\Users\heroe\OneDrive\桌面\play-gpt\vnov
# C:\Users\heroe\AppData\Roaming\Python\Python312\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from vnov.story.translator import Translator
from vnov.llms.deepseek import Deepseek
from vnov.data import Novel
import json

# %%
novel = Novel('datasets/yujie')

# %%
model = Deepseek()

# %%
trans = Translator(model)

# %%
trans.translate(novel)
# Out:
# [{'role': 'system', 'content': 'You are a professional **"Scene Information in Chinese" to "English Danbooru Tag"** translator. You are professional at converting scene information in chinese to Danbooru Tag without losing information. \nYou can use the following sample output to assist you(your output should be in the same format):\n```json\n{\n    "场景": [\n        "desolate_mountain",\n        "overcast",\n        "strong_wind",\n        "overgrown_grass"\n    ],\n    "动作": [\n        "wandering"\n    ],\n    "表情": [\n        "confused_expression",\n        "painful_expression"\n    ],\n    "服装": [\n        "tattered_jacket",\n        "wrinkled_shirt",\n        "worn_pants"\n    ]\n}\n```\n\n'}, {'role': 'user', 'content': '# Input:\n{\'场景\': [\'荒山\', \'阴云密布\', \'凛冽的风吹拂\', \'杂草丛生的地面\'], \'动作\': [\'在荒山上徘徊\'], \'表情\': [\'迷茫\', \'痛苦\'], \'服装\': [\'破旧的外套\', \'皱巴巴的衬衫\', \'磨损的裤子\']}\n\n# Instruction:\nPlease convert these four fields of input: "场景，动作，表情，服装" to English dambooru tag. If on
# ...
