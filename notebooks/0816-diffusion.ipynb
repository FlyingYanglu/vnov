# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from vnov.image_generation.diffusion import Diffusion

# %%
diffuser = Diffusion()
# Out:
# ...
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
prompt = "1girl, solo, headshot, upper chest, business attire, sexy luring expression, long hair, brown hair, chestnut brown hair, wavy hair, side-swept bangs, brown eyes, almond-shaped eyes, fair skin, rosy cheeks, soft pink lips, small nose, round chin, holding laptop, IT company office background, desks, computers, monitors, blurred background, modern office design, natural lighting, serene atmosphere, vibrant colors, oldest"
negative_prompt = "nsfw, lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry, artist name"

# %%
prompts = [prompt]*1
negative_prompts = [negative_prompt]*1

# %%
# image = diffuser.advanced_generate(prompt, negative_prompt)

# %%
image = diffuser.advanced_generate(prompts, negative_prompts)
# Out:
# torch.Size([1, 154, 2048]) torch.Size([1, 154, 2048]) torch.Size([1, 1280]) torch.Size([1, 1280])
#   0%|          | 0/28 [00:00<?, ?it/s]

# %%
image[0]
# Out:
# <PIL.Image.Image image mode=RGB size=1344x768>
