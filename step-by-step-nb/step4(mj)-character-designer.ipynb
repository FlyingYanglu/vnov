# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from vnov.story.midjourney_simple_char_designer import MidJourneySimpleCharDesigner
from vnov.llms.poe import Poe
from vnov.llms.deepseek import Deepseek
from vnov.data import Novel

# %%
model = Poe(email_account="yhb19991115@gmail.com")
# model = Deepseek()

# %%
novel = Novel( "datasets/yujie", "史金")

# %%
designer = CharacterDesigner(model)

# %%
designer.design_all_characters(novel, 
                               re_design=True, 
                               filter_threshold=0, 
                               base_unit="scene", 
                               context_choose_mode="dynamic_start", 
                               extra_contexts=6
                               )
# Out:
# Designing character 史金 1/140
# Estimated early stop count: 85
# Found 85 contexts for character 史金
# Detected early stop at 85 contexts, using 6 contexts to ensure enough information
# Designing character 陈金莲 2/140
# Found 85 contexts for character 陈金莲
# Detected early stop at 85 contexts, using 6 contexts to ensure enough information
# Designing character 叶笑天 3/140
# Found 1 contexts for character 叶笑天
# Designing character 火葬场工作人员 4/140
# Found 1 contexts for character 火葬场工作人员
# Designing character 秦霜 5/140
# Found 85 contexts for character 秦霜
# Detected early stop at 85 contexts, using 6 contexts to ensure enough information
# Designing character 路人 6/140
# Found 3 contexts for character 路人
# Designing character 警察 7/140
# Found 2 contexts for character 警察
# Designing character 保镖 8/140
# Found 11 contexts for character 保镖
# Designing character 秦枫 9/140
# Found 5 contexts for character 秦枫
# Designing character 杨自奎 10/140
# Found 85 contexts for character 杨自奎
# Detected early stop at 85 contexts, using 6 contexts to ensure enough information
# Designing character 阿东 11/140
# Found 85 contexts for character 阿东
# Detected early stop at 85 contexts, using 6 contexts to ensure enough information
# Designing character 代红伟 12/140
# Found 53 contexts for character 代红伟
# Designing character 马蓉 13/140
# Found 62 contexts for character 马蓉
# Designing character 杨爸 14/140
# Found 2 contexts for character 杨爸
# Designing character 胡正东 15/140
# Found 10 contexts for character 胡正东
# Designing character 路人甲 16/140
# Found 9 contexts for character 路人甲
# Designing character 无名女子 17/140
# Found 35 contexts for character 无名女子
# Designing character 无名女子的朋友 18/140
# Found 3 contexts for character 无名女子的朋友
# Designing character 路人乙 19/140
# Found 8 contexts for character 路人乙
# Designing character 阮俊 20/140
# Found 20 contexts for character 阮俊
# Designing character 无名保镖 21/140
# Found 5 contexts for character 无名保镖
# Designing character 小保安 22/140
# Found 1 contexts for character 小保安
# Designing character 黄毛 23/140
# Found 13 contexts for character 黄毛
# Designing character 孙小萌 24/140
# Found 64 contexts for character 孙小萌
# Designing character 徐梦娜 25/140
# Found 47 contexts for character 徐梦娜
# Designing character 保安 26/140
# Found 2 contexts for character 保安
# Designing character 张老板 27/140
# Found 1 contexts for character 张老板
# Designing character 吴龙飞 28/140
# Found 19 contexts for character 吴龙飞
# Designing character 权贵富商 29/140
# Found 1 contexts for character 权贵富商
# Designing character 陪酒女 30/140
# Found 1 contexts for character 陪酒女
# Designing character 无名男子 31/140
# Found 24 contexts for character 无名男子
# Designing character 黄毛青年 32/140
# Found 3 contexts for character 黄毛青年
# Designing character 性感女子 33/140
# Found 3 contexts for character 性感女子
# Designing character 邪里邪气的青年 34/140
# Found 3 contexts for character 邪里邪气的青年
# Designing character 无名青年1 35/140
# Found 1 contexts for character 无名青年1
# Designing character 无名青年2 36/140
# Found 1 contexts for character 无名青年2
# Designing character 无名青年3 37/140
# Found 1 contexts for character 无名青年3
# Designing character 无名青年4 38/140
# Found 1 contexts for character 无名青年4
# Designing character 无名青年5 39/140
# Found 1 contexts for character 无名青年5
# Designing character 陆大海 40/140
# Found 17 contexts for character 陆大海
# Designing character 无名保安1 41/140
# Found 1 contexts for character 无名保安1
# Designing character 无名保安2 42/140
# Found 1 contexts for character 无名保安2
# Designing character 无名保安3 43/140
# Found 1 contexts for character 无名保安3
# Designing character 无名保安4 44/140
# Found 1 contexts for character 无名保安4
# Designing character 无名保安 45/140
# Found 2 contexts for character 无名保安
# Designing character 驾驶员 46/140
# Found 1 contexts for character 驾驶员
# Designing character 医生 47/140
# Found 1 contexts for character 医生
# Designing character 护士 48/140
# Found 7 contexts for character 护士
# Designing character 黄三 49/140
# Found 12 contexts for character 黄三
# Designing character 小弟 50/140
# Found 5 contexts for character 小弟
# Designing character 无名商家 51/140
# Found 1 contexts for character 无名商家
# Designing character 马士博 52/140
# Found 12 contexts for character 马士博
# Designing character 无名副手 53/140
# Found 1 contexts for character 无名副手
# Designing character 无名负责人 54/140
# Found 2 contexts for character 无名负责人
# Designing character 王总 55/140
# Found 1 contexts for character 王总
# Designing character 商业调查科负责人 56/140
# Found 1 contexts for character 商业调查科负责人
# Designing character 凯尔副总陈倩 57/140
# Found 1 contexts for character 凯尔副总陈倩
# Designing character 无名角色 58/140
# Found 3 contexts for character 无名角色
# Designing character 钟良宽 59/140
# Found 13 contexts for character 钟良宽
# Designing character 大堂经理 60/140
# Found 2 contexts for character 大堂经理
# Designing character 客户经理 61/140
# Found 2 contexts for character 客户经理
# Designing character 肖雅 62/140
# Found 10 contexts for character 肖雅
# Designing character 其他男生 63/140
# Found 2 contexts for character 其他男生
# Designing character 无名女生 64/140
# Found 2 contexts for character 无名女生
# Designing character 无名男生 65/140
# Found 2 contexts for character 无名男生
# Designing character 无名同学 66/140
# Found 3 contexts for character 无名同学
# Designing character 同学 67/140
# Found 1 contexts for character 同学
# Designing character 黎莹 68/140
# Found 7 contexts for character 黎莹
# Designing character 代七 69/140
# Found 15 contexts for character 代七
# Designing character 高年级学生 70/140
# Found 2 contexts for character 高年级学生
# Designing character 管家 71/140
# Found 7 contexts for character 管家
# Designing character 史金的内心 72/140
# Found 0 contexts for character 史金的内心
# WARNING: Context is empty, Character info might be random
# Error designing character 史金的内心: cannot access local variable 'response_json' where it is not associated with a value
# Designing character 代仲青 73/140
# Found 13 contexts for character 代仲青
# Designing character 田守芳 74/140
# Found 4 contexts for character 田守芳
# Designing character 邹圣英 75/140
# Found 1 contexts for character 邹圣英
# Designing character 代总 76/140
# Found 1 contexts for character 代总
# Designing character 佣人 77/140
# Found 1 contexts for character 佣人
# Designing character 中年男子 78/140
# Found 1 contexts for character 中年男子
# Designing character 德爷 79/140
# Found 14 contexts for character 德爷
# Designing character 江城高管 80/140
# Found 1 contexts for character 江城高管
# Designing character 心腹 81/140
# Found 1 contexts for character 心腹
# Designing character 村民 82/140
# Found 4 contexts for character 村民
# Designing character 村民代表 83/140
# Found 2 contexts for character 村民代表
# Designing character 高丽梅 84/140
# Found 5 contexts for character 高丽梅
# Designing character 代家 85/140
# Found 1 contexts for character 代家
# Designing character 无名男子1 86/140
# Found 1 contexts for character 无名男子1
# Designing character 无名男子2 87/140
# Found 1 contexts for character 无名男子2
# Designing character 无名男子3 88/140
# Found 1 contexts for character 无名男子3
# Designing character 无名男子4 89/140
# Found 1 contexts for character 无名男子4
# Designing character 无名学生1 90/140
# Found 1 contexts for character 无名学生1
# Designing character 无名学生2 91/140
# Found 1 contexts for character 无名学生2
# Designing character 客服 92/140
# Found 2 contexts for character 客服
# Designing character 助理 93/140
# Found 8 contexts for character 助理
# Designing character 性感女伴 94/140
# Found 2 contexts for character 性感女伴
# Designing character 秦小姐 95/140
# Found 1 contexts for character 秦小姐
# Designing character 小助理 96/140
# Found 1 contexts for character 小助理
# Designing character 大管家 97/140
# Found 2 contexts for character 大管家
# Designing character 钱九 98/140
# Found 19 contexts for character 钱九
# Designing character 表姐 99/140
# Found 1 contexts for character 表姐
# Designing character 彩票店老板 100/140
# Found 2 contexts for character 彩票店老板
# Designing character 无名路人甲 101/140
# Found 1 contexts for character 无名路人甲
# Designing character 无名路人乙 102/140
# Found 1 contexts for character 无名路人乙
# Designing character 杨自奎的朋友 103/140
# Found 1 contexts for character 杨自奎的朋友
# Designing character 彩票中心工作人员 104/140
# Found 1 contexts for character 彩票中心工作人员
# Designing character 学生甲 105/140
# Found 2 contexts for character 学生甲
# Designing character 学生乙 106/140
# Found 2 contexts for character 学生乙
# Designing character 学生丙 107/140
# Found 1 contexts for character 学生丙
# Designing character 驾驶员天南 108/140
# Found 2 contexts for character 驾驶员天南
# Designing character 天南 109/140
# Found 8 contexts for character 天南
# Designing character 黑影 110/140
# Found 1 contexts for character 黑影
# Designing character 小五 111/140
# Found 8 contexts for character 小五
# Designing character 无名病人 112/140
# Found 2 contexts for character 无名病人
# Designing character 黎莹老师 113/140
# Found 3 contexts for character 黎莹老师
# Designing character 为首男子 114/140
# Found 15 contexts for character 为首男子
# Designing character 化妆护士 115/140
# Found 6 contexts for character 化妆护士
# Designing character 带头大哥 116/140
# Found 10 contexts for character 带头大哥
# Designing character 赖三 117/140
# Found 50 contexts for character 赖三
# Designing character 女护士 118/140
# Found 1 contexts for character 女护士
# Designing character 江河 119/140
# Found 29 contexts for character 江河
# Designing character 伪娘 120/140
# Found 2 contexts for character 伪娘
# Designing character 手下 121/140
# Found 1 contexts for character 手下
# Designing character 无名堂口话事人 122/140
# Found 2 contexts for character 无名堂口话事人
# Designing character 无名手下 123/140
# Found 1 contexts for character 无名手下
# Designing character 无名堂主1 124/140
# Found 1 contexts for character 无名堂主1
# Designing character 无名堂主2 125/140
# Found 1 contexts for character 无名堂主2
# Designing character 无名堂主3 126/140
# Found 1 contexts for character 无名堂主3
# Designing character 无名堂主4 127/140
# Found 1 contexts for character 无名堂主4
# Designing character 无名堂主5 128/140
# Found 1 contexts for character 无名堂主5
# Designing character 无名堂主6 129/140
# Found 1 contexts for character 无名堂主6
# Designing character 无名堂主7 130/140
# Found 1 contexts for character 无名堂主7
# Designing character 无名堂主8 131/140
# Found 1 contexts for character 无名堂主8
# Designing character 秦霜的三哥 132/140
# Found 1 contexts for character 秦霜的三哥
# Designing character 钟老板 133/140
# Found 1 contexts for character 钟老板
# Designing character 牛人 134/140
# Found 1 contexts for character 牛人
# Designing character 秦家人 135/140
# Found 1 contexts for character 秦家人
# Designing character 罗斯家族 136/140
# Found 1 contexts for character 罗斯家族
# Designing character 异人组 137/140
# Found 3 contexts for character 异人组
# Designing character 科技巨头 138/140
# Found 1 contexts for character 科技巨头
# Designing character 异人组织 139/140
# Found 1 contexts for character 异人组织
# Designing character 国际组织 140/140
# Found 1 contexts for character 国际组织
# {'史金': {'Name': '史金',
#   'Gender': 'Male',
#   'Description': '史金是一位经历了巨变的年轻人，内心饱受折磨，充满了对未来的渴望与不安。作为豪门千金秦霜心目中的理想对象，他不仅要面对自身的挑战，还要努力克服两人之间的重重阻碍。他的绿色眼睛中闪烁着坚定的光芒和温柔的情感，表明他对秦霜的深厚情感。他在日常生活中展现出成熟与自信，努力用行动证明自己的决心。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'ikemen',
#   'Appearance': {'Hair': ['light_brown_hair',
#     'medium_length_hair',
#     'wavy_hair'],
#    'Eyes': ['green_eyes', 'gentle_eyes'],
#    'Skin': ['fair_skin'],
#    'Lips': ['full_lips'],
#    'Nose': ['straight_nose'],
#    'Chin': ['strong_chin'],
#    'Body': {'Height': 'tall', 'Build': 'athletic', 'Muscle': 'Strong'}}},
#  '陈金莲': {'Name': '陈金莲',
#   'Gender': 'Female',
#   'Description': '陈金莲是一位外表出众、魅力四射的女性，拥有一双深邃的桃花眼，仿佛能看透人心。在得知史金的成功后，她内心深处感到震惊与兴奋，逐渐对他产生了新的看法。她在校园中游刃有余，尽管表面上保持高雅和冷漠，但内心深处却充满了对爱的渴望和复杂的情感。她渴望在阮俊面前展示自己，同时又不甘心被他人所左右。陈金莲的生活奢华而放纵，享受着美好的一切，却常常感到无趣与空虚，仿佛她的每一次追求都是一场无尽的梦。如今，她对史金的重新认识让她心中暗潮涌动，思考着未来的可能性。',
#   'Role': 'antagonist',
#   'Anime character archetype': 'femme fatale',
#   'Appearance': {'Hair': ['long hair',
#     'wavy hair',
#     'light purple hair',
#     'silver hair'],
#    'Eyes': ['peach eyes', 'glossy eyes', 'cat-like eyes', 'hazel eyes'],
#    'Skin': ['fair skin', 'smooth skin'],
#    'Lips': ['full lips', 'dark red lips'],
#    'Nose': ['small nose', 'delicate nose'],
#    'Chin': ['pointed chin', 'slim chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Breast': 'big'}}},
#  '叶笑天': {'Name': '叶笑天',
#   'Gender': 'Male',
#   'Description': '叶笑天是一位自信且风趣的年轻男性，性格中透着一丝戏谑和不羁。他总是面带微笑，给人一种轻松自在的感觉，但内心却隐藏着阴暗的秘密与复杂的情感。他是个魅力四射的男人，过往的经历让他变得狡猾而具有操控他人情感的能力。他对爱情的冷酷态度使他在感情中游刃有余，但内心深处却渴望真正的情感连接。',
#   'Role': 'antagonist',
#   'Anime character archetype': 'psychopath',
#   'Appearance': {'Hair': ['black hair', 'long hair', 'styled hair'],
#    'Eyes': ['red eyes', 'sharp eyes'],
#    'Skin': ['pale skin'],
#    'Lips': ['thin lips', 'smirking lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['sharp chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Muscle': 'weak'}}},
#  '火葬场工作人员': {'Name': '火葬场工作人员',
#   'Gender': 'Male',
#   'Description': '火葬场工作人员是一位身材魁梧的男性，面容冷峻且带有一丝疲惫。他的眼神深邃，似乎看透了生死，常常流露出对生命的无奈和淡漠。他的工作让他习惯了死亡的气息，虽然外表坚硬，但内心却藏着对生命的尊重与思考。他穿着简单的工作服，显得朴实无华，却透着一股沉稳的气质。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['short hair', 'dark hair', 'messy hair'],
#    'Eyes': ['dark eyes', 'deep-set eyes'],
#    'Skin': ['pale skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '秦霜': {'Name': '秦霜',
#   'Gender': 'Female',
#   'Description': '秦霜是一位优雅且果断的豪门千金，她不仅聪慧且有领导力，面对突发事件时展现出强大的气场。在与史金的互动中，她既展现出调皮的一面，也不失温柔与关心，内心深处对情感的渴求与挣扎让她的人物形象更加立体。她微卷的长发在阳光下闪烁着迷人的光泽，明亮的眼眸中流露出坚定与温柔的交织，既能令人感到安全，又能令人畏惧。秦霜在努力维护自己形象的同时，也在逐渐接受内心真实的感情与情绪，尤其是在面对与史金的关系时，她更加展现出既调皮又坚强的特质。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'ojou-sama',
#   'Appearance': {'Hair': ['long hair',
#     'wavy hair',
#     'platinum blonde hair',
#     'light purple hair'],
#    'Eyes': ['bright eyes', 'emerald green eyes', 'sharp gaze'],
#    'Skin': ['fair skin', 'smooth skin', 'lightly tanned'],
#    'Lips': ['full lips', 'rosy lips'],
#    'Nose': ['delicate nose'],
#    'Chin': ['pointed chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Breast': 'Medium'}}},
#  '路人': {'Name': '路人',
#   'Gender': 'Male',
#   'Description': '路人是一个外表普通却内心丰富的人，他在繁华的都市中显得格外淡然。尽管身处喧嚣的环境，他却总是保持着一份宁静和冷静，仿佛对周围的一切都略显无动于衷。他的目光时常流露出思考和观察的深邃，似乎在思索着生活的意义。路人虽然身材普通，但他身上的气质却让人难以忽视，似乎隐藏着某种不为人知的故事。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'messy hair'],
#    'Eyes': ['gray eyes', 'piercing gaze'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['normal chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender'}}},
#  '警察': {'Name': '警察',
#   'Gender': 'Male',
#   'Description': '警察是一位勇敢而坚定的执法人员，面对混乱的现场，他始终保持沉着冷静，拥有强烈的正义感。他的职业使他目睹了许多黑暗的事情，但他从不退缩，始终为保护无辜而战。他的身材高大，肌肉结实，给人一种可靠和信任的感觉。尽管工作压力巨大，他依然保持着温和的微笑，试图缓解紧张的气氛。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'messy hair'],
#    'Eyes': ['sharp eyes', 'dark blue eyes'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular'}}},
#  '保镖': {'Name': '冷锋',
#   'Gender': 'Male',
#   'Description': '冷锋是一名沉稳冷酷的保镖，身材魁梧，常年训练使他的肌肉线条分明，给人强烈的安全感。他的眼神犀利，似乎能洞穿一切，时刻警惕着周围的动静。他虽然外表冷峻，但内心深处有一份对弱者的保护欲，尤其是对他所守护的对象。他的职业使他不得不隐藏自己的情感，但在关键时刻，他会毫不犹豫地出手保护他所珍视的人。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'yankee',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'spiky hair'],
#    'Eyes': ['sharp eyes', 'dark eyes'],
#    'Skin': ['tan skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['strong nose'],
#    'Chin': ['chiseled chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular'}}},
#  '秦枫': {'Name': '秦枫',
#   'Gender': 'Male',
#   'Description': '秦枫是一位果断而有魅力的年轻男子，身为秦家的长子，他具备强烈的责任感和领导才能。他的性格外向，常常以幽默和直率的方式与他人交流，但内心却隐藏着一些对家庭压力的焦虑。他精通商业，善于利用人际关系，但也因为家族的期望而感到束缚。他的外表英俊，给人一种不容小觑的气场。',
#   'Role': 'male protagonist',
#   'Anime character archetype': 'ikemen',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'stylish'],
#    'Eyes': ['sharp eyes', 'dark blue', 'determined'],
#    'Skin': ['fair skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Muscle': 'Strong'}}},
#  '杨自奎': {'Name': '杨自奎',
#   'Gender': 'Male',
#   'Description': '杨自奎是一个性格外向、幽默风趣的大学生，热爱生活并时常开玩笑。他对身边的每一个人都充满了热情，尤其在朋友遇到困难时，愿意提供帮助。最近，他目睹了同班同学史金的转学和成长，对其产生了崇拜之情，同时也开始反思自己的不成熟。在班上，他对新同学布加迪王子的到来感到兴奋，对他充满了好奇。尽管内心也有些小嫉妒，但他依然努力保持乐观和积极的态度。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'genki boy',
#   'Appearance': {'Hair': ['short hair', 'light blue hair', 'spiky hair'],
#    'Eyes': ['hazel eyes', 'sparkling eyes'],
#    'Skin': ['fair skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['pointed chin'],
#    'Body': {'Height': 'medium', 'Build': 'athletic', 'Muscle': 'weak'}}},
#  '阿东': {'Name': '阿东',
#   'Gender': 'Male',
#   'Description': '阿东是一名年轻的保镖，身材健壮，拥有精湛的武术技巧。他在保护秦霜时展现出强烈的责任感，对她的安全非常重视。性格沉稳冷静，时常用幽默来化解紧张气氛，但在关键时刻却毫不留情地保护她。面对史金的威胁，他毫不畏惧，展现出坚定的态度。他从小跟随师父习武，后来进入特种部队，内心渴望能在危机时刻成为他人可靠的后盾。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['spiky hair',
#     'light blue hair',
#     'medium length hair'],
#    'Eyes': ['sharp eyes', 'amber eyes'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['defined chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '代红伟': {'Name': '代红伟',
#   'Gender': 'Male',
#   'Description': '代红伟是一位富家公子，性格张扬且自信，常常流露出高人一等的优越感。他是个典型的追求者，对秦霜抱有强烈的执念，常常在她面前展现出自己的权势与财富。但内心深处，代红伟却也有着无法言说的孤独感，渴望被真正理解和认可。',
#   'Role': 'male antagonist',
#   'Anime character archetype': 'rival',
#   'Appearance': {'Hair': ['brown hair', 'styled hair', 'short hair'],
#    'Eyes': ['sharp eyes', 'golden eyes'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['defined chin'],
#    'Body': {'Height': 'tall', 'Build': 'athletic', 'Muscle': 'Strong'}}},
#  '马蓉': {'Name': '马蓉',
#   'Gender': 'Female',
#   'Description': '马蓉是一位活泼开朗的少女，性格外向，善于交际，喜欢和朋友们分享生活中的点滴。她总是带着灿烂的笑容，拥有强烈的正义感和对朋友的无私支持。在她的眼中，生活充满乐趣，喜欢帮助别人，是一位充满活力的‘阳光女孩’。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'genki girl',
#   'Appearance': {'Hair': ['long hair', 'wavy hair', 'brown hair'],
#    'Eyes': ['big eyes', 'sparkling eyes', 'green eyes'],
#    'Skin': ['fair skin'],
#    'Lips': ['full lips', 'pink lips'],
#    'Nose': ['small nose'],
#    'Chin': ['pointed chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Breast': 'Medium'}}},
#  '杨爸': {'Name': '杨爸',
#   'Gender': 'Male',
#   'Description': '杨爸是一位中年男性，充满了生活的智慧和幽默感。他热爱汽车，尤其是豪车，常常梦想着拥有一辆布加迪。他的性格开朗，喜欢和家人分享自己的兴趣，尤其是在与儿子一起欣赏美丽的汽车时。他总是充满热情，喜欢拍照记录生活的美好瞬间。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'genki boy',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'slightly graying'],
#    'Eyes': ['bright eyes', 'small eyes', 'sparkling eyes'],
#    'Skin': ['light skin', 'slightly tanned'],
#    'Lips': ['full lips', 'smiling'],
#    'Nose': ['average nose'],
#    'Chin': ['rounded chin'],
#    'Body': {'Height': 'medium', 'Build': 'average', 'Muscle': 'weak'}}},
#  '胡正东': {'Name': '胡正东',
#   'Gender': 'Male',
#   'Description': '胡正东是一个活泼开朗的大学男生，性格外向且充满幽默感，常常能在同学中带动气氛。他是班级的班长，对同学们关怀备至，乐于助人。尽管外表看似普通，但他总是能用自己的智慧和机智吸引周围的注意。他对时尚有一定的敏感度，喜爱尝试不同的穿搭风格，努力在同学中树立自己的形象。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'genki boy',
#   'Appearance': {'Hair': ['short hair', 'brown hair', 'spiky hair'],
#    'Eyes': ['bright eyes', 'brown eyes'],
#    'Skin': ['light skin'],
#    'Lips': ['full lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['rounded chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender'}}},
#  '路人甲': {'Name': '路人甲',
#   'Gender': 'Male',
#   'Description': '路人甲是一位普通的路人，生活在城市的边缘，目光敏锐，时常对周围的奢华和繁华感到好奇与羡慕。他总是在街头观察着那些富有的年轻人，心中暗自思忖，梦想着有一天能够与他们平起平坐。虽然他并不富裕，但他乐观开朗，善于交际，喜欢和朋友分享自己的想法和感受。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'genki boy',
#   'Appearance': {'Hair': ['short hair', 'brown hair', 'messy hair'],
#    'Eyes': ['bright eyes', 'green eyes'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['average nose'],
#    'Chin': ['pointed chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender'}}},
#  '无名女子': {'Name': '无名女子',
#   'Gender': 'Female',
#   'Description': '无名女子是一位充满神秘感的女性，身上散发着独特的魅力。她聪慧而自信，目光中透露出一丝坚定。她在豪门圈子中游刃有余，善于观察周围人的情绪与欲望。虽然出身普通，但她通过自己的努力与魅力赢得了大家的关注。无名女子内心渴望真正的爱情，时常在繁华的表象下思考自己的未来。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'genki girl',
#   'Appearance': {'Hair': ['long_hair', 'wavy_hair', 'brown_hair'],
#    'Eyes': ['large_eyes', 'green_eyes'],
#    'Skin': ['fair_skin'],
#    'Lips': ['full_lips', 'light_pink_lips'],
#    'Nose': ['small_nose'],
#    'Chin': ['soft_chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Breast': 'Medium'}}},
#  '无名女子的朋友': {'Name': '无名女子的朋友',
#   'Gender': 'Female',
#   'Description': '无名女子的朋友是一位充满活力和追求时尚的年轻女性。她总是渴望进入华丽的富人圈，梦想能够嫁入豪门。她性格开朗，善于交际，时常鼓励周围的人追求梦想。虽然偶尔显得有些天真，但她的热情和朝气让她在朋友中备受欢迎。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'genki girl',
#   'Appearance': {'Hair': ['long hair',
#     'wavy hair',
#     'light brown hair',
#     'hair ribbon'],
#    'Eyes': ['big eyes', 'sparkling eyes', 'green eyes'],
#    'Skin': ['fair skin'],
#    'Lips': ['full lips', 'pink lips'],
#    'Nose': ['small nose'],
#    'Chin': ['pointed chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Breast': 'Medium'}}},
#  '路人乙': {'Name': '路人乙',
#   'Gender': 'Male',
#   'Description': '路人乙是一位普通的大学生，性格开朗随和，喜欢与人交谈。他热爱社交，总是乐于分享周围发生的趣事。尽管他没有特别的背景和财富，但他的幽默感和友善的态度总能让他在朋友中受到欢迎。他常常是校园里热议的焦点，尤其是对于那些富二代的生活方式充满了好奇和羡慕。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'genki boy',
#   'Appearance': {'Hair': ['short hair', 'brown hair', 'messy hair'],
#    'Eyes': ['brown eyes', 'bright eyes'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['average nose'],
#    'Chin': ['average chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender'}}},
#  '阮俊': {'Name': '阮俊',
#   'Gender': 'Male',
#   'Description': '阮俊是一位自信而温柔的男生，身为学生会会长，他不仅外形俊朗，还拥有出众的才华和背景。他的家庭富裕，父亲经营着成功的建筑公司，因此他在校园中备受瞩目。阮俊潇洒自然的性格使得他在众多女生中颇受欢迎，但他内心深处却对感情保持着一份清醒和理智。他热爱生活，喜欢结交朋友，拥有强烈的责任感和领导能力。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'ikemen',
#   'Appearance': {'Hair': ['black hair', 'medium length', 'stylish hairstyle'],
#    'Eyes': ['brown eyes', 'sharp gaze'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips', 'slightly curved smile'],
#    'Nose': ['straight nose'],
#    'Chin': ['defined chin'],
#    'Body': {'Height': 'tall', 'Build': 'athletic', 'Muscle': 'Strong'}}},
#  '无名保镖': {'Name': '无名保镖',
#   'Gender': 'Male',
#   'Description': '无名保镖是一位身手不凡的护卫，性格冷静沉稳，专注于保护雇主。他体格健壮，面无表情，总是给人一种强烈的安全感。他在黑暗的地下世界中游刃有余，时常展现出超乎寻常的战斗能力。尽管他不愿多言，但对正义的执着与对雇主的忠诚让他在复杂的环境中显得无比可靠。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'spiky hair'],
#    'Eyes': ['sharp eyes', 'dark eyes'],
#    'Skin': ['tan skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular'}}},
#  '小保安': {'Name': '小保安',
#   'Gender': 'Male',
#   'Description': '小保安是一名年轻的保安，性格忠诚而认真。他总是努力履行自己的职责，尽管他的外表看起来有些稚嫩。他渴望得到认可，并希望能在工作中证明自己的能力，但有时他的天真和好奇心会让他陷入困境。他对工作充满热情，但有时会因为好奇心而做出一些冒失的举动。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'genki boy',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'messy hair'],
#    'Eyes': ['bright eyes', 'green eyes'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['slight nose'],
#    'Chin': ['rounded chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Muscle': 'Weak'}}},
#  '黄毛': {'Name': '黄毛',
#   'Gender': 'Male',
#   'Description': '黄毛是一名年轻的混混，性格冲动且好胜，常常表现出自信和傲慢。他在江城的地下圈子中活跃，擅长带领小弟和参与斗殴，虽然外表粗犷，但内心渴望得到认可和尊重。他对代红伟充满依赖，一心想为他出头，因此常常参与一些不太理智的计划。',
#   'Role': 'antagonist',
#   'Anime character archetype': 'fanatic',
#   'Appearance': {'Hair': ['blonde hair', 'spiky hair'],
#    'Eyes': ['sharp eyes', 'dark eyes'],
#    'Skin': ['tanned skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['flat nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'medium', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '孙小萌': {'Name': '孙小萌',
#   'Gender': 'Female',
#   'Description': '孙小萌是一位积极向上的女大学生，性格开朗，乐于助人。作为学校勤工俭学的负责人，她总是努力帮助同学们找到合适的工作。虽然有时会因为勉强自己而感到疲惫，但她从不表现出来，总是保持着微笑。她在学习和工作中都非常认真，给人一种可靠的感觉。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'genki girl',
#   'Appearance': {'Hair': ['long_hair', 'brown_hair', 'twintails'],
#    'Eyes': ['big_eyes', 'brown_eyes'],
#    'Skin': ['fair_skin'],
#    'Lips': ['full_lips', 'pink_lips'],
#    'Nose': ['small_nose'],
#    'Chin': ['pointed_chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Breast': 'Medium'}}},
#  '徐梦娜': {'Name': '徐梦娜',
#   'Gender': 'Female',
#   'Description': '徐梦娜是一位自信而有主见的女性，作为勤工俭学的负责人，她总是给人一种强势而优雅的感觉。她对自己的形象非常注重，喜欢穿着时尚，并且拥有敏锐的观察力。性格中带有一点傲娇，但内心也有着柔软的一面，尤其是在面对真正重要的人时，她会展现出少许的温暖和关怀。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'ojou-sama',
#   'Appearance': {'Hair': ['long hair', 'wavy hair', 'brown hair'],
#    'Eyes': ['green eyes', 'sharp eyes'],
#    'Skin': ['fair skin'],
#    'Lips': ['full lips', 'pink lips'],
#    'Nose': ['petite nose'],
#    'Chin': ['pointed chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Breast': 'Medium'}}},
#  '保安': {'Name': '保安',
#   'Gender': 'Male',
#   'Description': '保安是一位身材魁梧、气宇轩昂的男性，常常站在学校门口，面带微笑，给人一种可靠的安全感。他的神情严肃但不失温和，能够在紧张的氛围中缓解他人的不安。他对待工作非常认真，时刻关注着周围的动静，性格沉稳、谨慎，给人一种值得信赖的印象。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'otouto',
#   'Appearance': {'Hair': ['short hair', 'black hair'],
#    'Eyes': ['sharp eyes', 'brown eyes'],
#    'Skin': ['tan skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '张老板': {'Name': '张老板',
#   'Gender': 'Male',
#   'Description': '张老板是一位中年商人，经营着多种饮料和零食，外表消瘦却气质不凡。他的商业头脑敏锐，深知市场运作的机制，给人一种精明干练的感觉。他待人热情，却也不失防备，身后常带有保镖，显示出他在商界的地位和影响力。',
#   'Role': 'male protagonist',
#   'Anime character archetype': 'otaku',
#   'Appearance': {'Hair': ['short hair', 'dark brown hair'],
#    'Eyes': ['sharp eyes', 'brown eyes'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips', 'neutral lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['sharp chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Muscle': 'weak'}}},
#  '吴龙飞': {'Name': '吴龙飞',
#   'Gender': 'Male',
#   'Description': '吴龙飞是一位清瘦的大学生，性格玩世不恭却又极具敏锐的思维。他有着一头蓬松的头发和一副眼镜，常常给人一种呆萌的感觉。虽然外表看似懒散，但他在计算机技术方面却相当出色，时常沉迷于技术的世界中，思考着各种互联网的可能性与创意。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['fluffy_hair', 'black_hair', 'messy_hair'],
#    'Eyes': ['sleepy_eyes', 'dark_eyes'],
#    'Skin': ['light_skin'],
#    'Lips': ['thin_lips'],
#    'Nose': ['small_nose'],
#    'Chin': ['pointed_chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Muscle': 'Weak'}}},
#  '权贵富商': {'Name': '权贵富商',
#   'Gender': 'Male',
#   'Description': '权贵富商是一位身处高档区域的成功男性，拥有无与伦比的魅力和权力。他总是穿着整洁的西装，身上散发着高贵而自信的气息。喜欢在奢华的场合中享受生活，他的眼神中透着深邃的智慧和一丝神秘。他的性格外向而风趣，能够轻松与周围的人交谈，然而他内心却隐藏着对权力和财富的无尽渴望。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'ikemen',
#   'Appearance': {'Hair': ['short hair', 'slicked back', 'dark brown hair'],
#    'Eyes': ['sharp eyes', 'golden eyes'],
#    'Skin': ['fair skin'],
#    'Lips': ['full lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['defined chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular'}}},
#  '陪酒女': {'Name': '玲子',
#   'Gender': 'Female',
#   'Description': '玲子是一位迷人的陪酒女，拥有一头闪耀的红色长发，搭配着娇艳的妆容和高档的服饰。她的性格外向，擅长与人交谈，总是带着温暖的微笑，能让身边的人感到轻松愉快。尽管她的生活充满奢华与喧嚣，内心却渴望找到真正的爱情与理解。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'deredere',
#   'Appearance': {'Hair': ['long hair', 'red hair', 'wavy hair'],
#    'Eyes': ['green eyes', 'sparkling eyes'],
#    'Skin': ['fair skin'],
#    'Lips': ['full lips', 'red lips'],
#    'Nose': ['small nose'],
#    'Chin': ['delicate chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Breast': 'Medium'}}},
#  '无名男子': {'Name': '无名男子',
#   'Gender': 'Male',
#   'Description': '无名男子是一位神秘而冷酷的角色，常常穿梭于人群中，似乎总是与周围的喧嚣格格不入。他的眼神透着一丝倔强和不屈，给人一种深不可测的感觉。虽然外表看似无情，但他内心深处却隐藏着对正义的坚定追求。他的出现总是伴随着紧张的气氛，令人感到他似乎在追寻着什么重要的东西。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['black hair', 'medium length', 'spiky'],
#    'Eyes': ['blue eyes', 'sharp gaze'],
#    'Skin': ['pale skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['sharp chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Muscle': 'Strong'}}},
#  '黄毛青年': {'Name': '黄毛青年',
#   'Gender': 'Male',
#   'Description': '黄毛青年是一位身材高挑、气质张扬的年轻人。他的金色头发随意地披散着，给人一种不羁的感觉。他性格狂妄，常常在朋友面前展示自己的优越感，尤其在酒吧等场合。他对女性颇有吸引力，总是能轻松引起她们的注意。然而，他内心深处却藏着对过去的怨恨，特别是对他认为欠自己钱财的秦霜。他的目光中透出一丝阴险，给人一种心机深沉的印象。',
#   'Role': 'antagonist',
#   'Anime character archetype': 'rival',
#   'Appearance': {'Hair': ['blonde', 'spiky hair', 'messy hair'],
#    'Eyes': ['red eyes', 'sharp eyes'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['pointed nose'],
#    'Chin': ['sharp chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '性感女子': {'Name': '性感女子',
#   'Gender': 'Female',
#   'Description': '性感女子是一位魅惑而神秘的女性，散发着强烈的吸引力。她的外貌性感而大胆，身穿暴露的服装，彰显出她的自信和不羁。尽管身处喧闹的包间，她的眼神中总带着一丝冷淡与挑衅，似乎在玩弄着周围人的心思。她的背景故事令人好奇，可能曾经历过无数的风波，成为了如今的她。',
#   'Role': 'female antagonist',
#   'Anime character archetype': 'femme fatale',
#   'Appearance': {'Hair': ['blonde hair',
#     'long hair',
#     'wavy hair',
#     'hair over one eye'],
#    'Eyes': ['red eyes', 'seductive eyes', 'cat eyes'],
#    'Skin': ['fair skin', 'smooth skin'],
#    'Lips': ['full lips', 'red lips'],
#    'Nose': ['small nose'],
#    'Chin': ['pointed chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Breast': 'Big'}}},
#  '邪里邪气的青年': {'Name': '黄毛青年',
#   'Gender': 'Male',
#   'Description': '黄毛青年是一位邪里邪气的角色，性格张扬且好斗。他总是带着一丝轻蔑的笑容，享受着对他人的挑衅与戏弄。他的外表给人一种不拘小节的感觉，身旁总是围绕着追随者，渴望表现出他在这个小圈子里的统治地位。',
#   'Role': 'antagonist',
#   'Anime character archetype': 'nihilistic villain',
#   'Appearance': {'Hair': ['blonde hair', 'spiky hair', 'dyed hair'],
#    'Eyes': ['red eyes', 'narrow eyes'],
#    'Skin': ['tan skin'],
#    'Lips': ['thin lips', 'smirking'],
#    'Nose': ['flat nose'],
#    'Chin': ['sharp chin'],
#    'Body': {'Height': 'medium', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '无名青年1': {'Name': '无名青年1',
#   'Gender': 'Male',
#   'Description': '无名青年1是一位年轻而强壮的男子，身材高大，给人一种威武的感觉。他是一个身手敏捷的战斗专家，常常在街头打斗中展现出惊人的力量和敏捷。他的性格果断，勇敢，面对敌人毫不退缩，总是冲在最前面，为朋友们提供保护。尽管身处暴力的环境中，他内心渴望着和平与正义。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'genki boy',
#   'Appearance': {'Hair': ['short hair', 'spiky hair', 'black hair'],
#    'Eyes': ['sharp eyes', 'blue eyes'],
#    'Skin': ['tanned skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular'}}},
#  '无名青年2': {'Name': '无名青年2',
#   'Gender': 'Male',
#   'Description': '无名青年2是一位年轻而充满活力的战斗者，身材高大且肌肉结实，展现出强烈的阳刚之气。他的眼神中闪烁着坚定的决心，仿佛在面对任何挑战时都能毫不畏惧。虽然他似乎有些冲动，但在战斗中表现出的敏捷与精准让人感受到他的实力。无名青年2的背景不为人知，但他似乎有着不平凡的经历，让他在这场战斗中毫不退缩。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'genki boy',
#   'Appearance': {'Hair': ['short_hair', 'spiky_hair', 'black_hair'],
#    'Eyes': ['sharp_eyes', 'green_eyes'],
#    'Skin': ['tan_skin'],
#    'Lips': ['thin_lips'],
#    'Nose': ['straight_nose'],
#    'Chin': ['square_chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '无名青年3': {'Name': '无名青年3',
#   'Gender': 'Male',
#   'Description': '无名青年3是一位勇敢而强壮的年轻战士，他在战斗中展现出惊人的力量和灵活性。他身形高大，肌肉发达，给人一种强烈的安全感。他的眼神坚定，充满了斗志，仿佛随时准备迎接挑战。尽管他身处危险之中，但他始终保持冷静，展现出无畏的英雄气概。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'yankee',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'spiky hair'],
#    'Eyes': ['sharp eyes', 'dark eyes'],
#    'Skin': ['tan skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular'}}},
#  '无名青年4': {'Name': '无名青年4',
#   'Gender': 'Male',
#   'Description': '无名青年4是一位年轻的战斗者，身材高大且肌肉结实，给人一种强烈的安全感。他的眼神坚定而有力，透露出不屈的意志。作为一名打架高手，他擅长快速的攻击和灵活的身手，常常用精准的踢击来制服对手。他的性格果断而勇敢，总是冲在最前面，面对挑战从不退缩。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'genki boy',
#   'Appearance': {'Hair': ['short hair', 'spiky hair', 'black hair'],
#    'Eyes': ['sharp eyes', 'green eyes'],
#    'Skin': ['tanned skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '无名青年5': {'Name': '无名青年5',
#   'Gender': 'Male',
#   'Description': '无名青年5是一位年轻且充满活力的男性，性格冲动且直率。他总是愿意为朋友挺身而出，尽管有时显得有些鲁莽。虽然面临着危险，但他从不退缩，反而在逆境中展现出勇气与决心。他的外表和气质都透露出一种叛逆的气息，令他在街头小混混中格外显眼。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'genki boy',
#   'Appearance': {'Hair': ['short_hair', 'spiky_hair', 'brown_hair'],
#    'Eyes': ['sharp_eyes', 'green_eyes'],
#    'Skin': ['light_skin'],
#    'Lips': ['thin_lips'],
#    'Nose': ['straight_nose'],
#    'Chin': ['angular_chin'],
#    'Body': {'Height': 'medium', 'Build': 'athletic', 'Muscle': 'Strong'}}},
#  '陆大海': {'Name': '陆大海',
#   'Gender': 'Male',
#   'Description': '陆大海是一位身材魁梧、气势逼人的年轻人，性格刚毅果断，处事冷静。他是一家酒吧的老板，拥有强大的背景和丰富的武术经验。他的眼神犀利，给人一种不容小觑的感觉，同时在面对威胁时也会展现出他冷酷的一面。他对朋友忠诚，对敌人毫不留情。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['short hair', 'dark hair', 'spiky hair'],
#    'Eyes': ['sharp eyes', 'dark eyes'],
#    'Skin': ['tanned skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular'}}},
#  '无名保安1': {'Name': '无名保安1',
#   'Gender': 'Male',
#   'Description': '无名保安1是一位身材魁梧的年轻男性，给人一种强烈的安全感。他的眼神如同猎豹般锐利，时刻关注着周围的动静。他身穿整齐的西装，展现出职业的干练与力量，态度冷酷无情，似乎经历过不少生死考验。他的外表虽然严肃，但在团队中他展现出极强的忠诚与责任感。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'male antagonist',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'spiky hair'],
#    'Eyes': ['sharp eyes', 'dark eyes'],
#    'Skin': ['tanned skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['strong nose'],
#    'Chin': ['square chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '无名保安2': {'Name': '无名保安2',
#   'Gender': 'Male',
#   'Description': '无名保安2是一位身材魁梧的年轻男性，面容严肃，浑身散发着强烈的阳刚之气。他的眼神如同鹰隼般锐利，似乎能洞察一切威胁。他身穿黑色西装，搭配白色衬衫和黑色领带，给人一种专业而又威严的感觉。虽然看起来严谨，但他内心深处却充满正义感，愿意保护无辜者不受伤害。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'spiky hair'],
#    'Eyes': ['sharp eyes', 'dark eyes'],
#    'Skin': ['tanned skin'],
#    'Lips': ['thin lips', 'neutral expression'],
#    'Nose': ['strong nose'],
#    'Chin': ['square chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '无名保安3': {'Name': '无名保安3',
#   'Gender': 'Male',
#   'Description': '无名保安3是一名高大魁梧的保安，身材结实，肌肉发达，给人一种强大的压迫感。他的眼神如刀锋般锐利，时常流露出警惕与果断的气息，仿佛随时准备应对突发事件。他在后海酒吧工作多年，积累了丰富的实战经验，性格冷静且坚毅，同时对同伴非常忠诚。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'yankee',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'spiky hair'],
#    'Eyes': ['sharp eyes', 'dark eyes'],
#    'Skin': ['tan skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['strong nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '无名保安4': {'Name': '无名保安4',
#   'Gender': 'Male',
#   'Description': '无名保安4是一位身材魁梧、气质强悍的保安，常常透着一股威严与冷酷。他的眼神如刀锋般锐利，似乎能洞悉一切，给人一种难以接近的感觉。他在工作时总是保持高度的警惕，随时准备应对突发的危险。他的经历让他在面对冲突时显得沉稳而果断，像一个真正的守护者。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'yankee',
#   'Appearance': {'Hair': ['short hair', 'dark hair', 'spiky hair'],
#    'Eyes': ['sharp eyes', 'dark eyes'],
#    'Skin': ['tanned skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['strong nose'],
#    'Chin': ['square chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '无名保安': {'Name': '无名保安',
#   'Gender': 'Male',
#   'Description': '无名保安是一位身材魁梧且表情严肃的男性，拥有强烈的责任感。他总是保持冷静，尽职尽责地保障场所的安全。尽管面无表情，他的眼神中透出一丝坚毅和决心。他的职业使他必须具备敏锐的观察力和应对突发事件的能力，身上散发着一股无法忽视的威严。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'spiky hair'],
#    'Eyes': ['sharp eyes', 'dark eyes'],
#    'Skin': ['tanned skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['strong nose'],
#    'Chin': ['square chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular'}}},
#  '驾驶员': {'Name': '驾驶员',
#   'Gender': 'Male',
#   'Description': '驾驶员是一位年轻而机警的男性，拥有出色的驾驶技术和敏锐的反应能力。他总是保持冷静，面对任何紧急情况都能迅速做出判断。他的外表看起来比较随意，但却散发出一种可靠的气场，令乘客感到安心。他的目光坚定而自信，似乎总是能够看穿前方的道路。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'ikemen',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'messy hair'],
#    'Eyes': ['sharp eyes', 'dark eyes'],
#    'Skin': ['tanned skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular'}}},
#  '医生': {'Name': '医生',
#   'Gender': 'Male',
#   'Description': '医生是一位年轻且极具魅力的医疗专家，他拥有温和的外表和专业的态度，给患者带来安心的感觉。他的声音低沉而富有磁性，常常在紧张的氛围中给予患者以慰藉。医生的穿着整洁，白色的外科大衣下隐藏着他精致的衣着，始终保持着干净利落的形象。他不仅医术高超，而且在患者中颇受欢迎，常常被称为‘微笑的医生’。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'ikemen',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'stylish hair'],
#    'Eyes': ['blue eyes', 'sharp eyes'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips', 'slightly smiling lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['defined chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Muscle': 'Strong'}}},
#  '护士': {'Name': '小雅',
#   'Gender': 'Female',
#   'Description': '小雅是一位年轻而充满活力的护士，拥有一头浓密的黑发和清澈的眸子。她性格开朗，乐于助人，虽然工作繁忙，但总是尽力让病人感到舒适。尽管她化着浓妆，但依然展现出一份自然的美丽。小雅对待病人温柔体贴，但在面对暴力和威胁时，她也展现出坚定的决心与勇气。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'genki girl',
#   'Appearance': {'Hair': ['black hair', 'long hair', 'straight hair'],
#    'Eyes': ['blue eyes', 'large eyes'],
#    'Skin': ['fair skin'],
#    'Lips': ['pink lips'],
#    'Nose': ['small nose'],
#    'Chin': ['oval chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Breast': 'Medium'}}},
#  '黄三': {'Name': '黄三',
#   'Gender': 'Male',
#   'Description': '黄三是一位中年男子，外表粗犷，气质中透着一股强烈的暴力倾向。他是个心狠手辣的角色，常常为了保护自己的家人和兄弟不惜一切代价。他的愤怒和绝望源于对弟弟的保护欲，尤其在面对仇敌时，更是显得冷酷无情。黄三有着丰富的黑道经历，深知生存的法则，因此他在危险的环境中游刃有余，但内心也藏着对家人的深切关爱。',
#   'Role': 'male antagonist',
#   'Anime character archetype': 'mastermind villain',
#   'Appearance': {'Hair': ['short hair', 'blonde hair', 'slicked-back'],
#    'Eyes': ['narrow eyes', 'dark eyes', 'intimidating gaze'],
#    'Skin': ['tanned skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['broad nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '小弟': {'Name': '小弟',
#   'Gender': 'Male',
#   'Description': '小弟是一名年轻的小混混，虽然性格冲动且缺乏经验，但他在帮派中充当着重要的角色。他总是渴望得到认可和尊重，因此常常表现得非常激动和愤怒。他的外表显示出一丝叛逆，常常穿着街头时尚的衣服，脸上带着一股不屈的气势。他内心渴望能在江湖中获得一席之地，但对未来感到迷茫。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'genki boy',
#   'Appearance': {'Hair': ['short hair', 'spiky hair', 'black hair'],
#    'Eyes': ['sharp eyes', 'brown eyes'],
#    'Skin': ['tanned skin'],
#    'Lips': ['thin lips', 'slightly chapped lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Muscle': 'Weak'}}},
#  '无名商家': {'Name': '无名商家',
#   'Gender': 'Male',
#   'Description': '无名商家是一位神秘的商人，常常在夜晚出没于城市的各个角落。他身穿考究的西装，表面看似优雅，但透着一丝冷冽和狡诈。他善于交际，能言善辩，常常用巧妙的策略和丰富的商业头脑来达成交易。他的眼神中透露出锐利的观察力，仿佛能一眼看透对方的心思。',
#   'Role': 'antagonist',
#   'Anime character archetype': 'mastermind villain',
#   'Appearance': {'Hair': ['short hair', 'dark hair', 'slicked back'],
#    'Eyes': ['sharp eyes', 'piercing gaze', 'dark pupils'],
#    'Skin': ['pale skin'],
#    'Lips': ['thin lips', 'light pink lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Muscle': 'Weak'}}},
#  '马士博': {'Name': '马士博',
#   'Gender': 'Male',
#   'Description': '马士博是一位精明且富有魅力的商业经理，总是表现出自信与从容。他的面容俊朗，气质优雅，给人一种高高在上的感觉。平时他待人温和，但在商业谈判中却表现出强硬的立场和聪明的策略，能够迅速洞察对方的意图。他的职业生涯充满挑战，背后隐藏着他对成功的渴望和对权力的追求。',
#   'Role': 'antagonist',
#   'Anime character archetype': 'mastermind villain',
#   'Appearance': {'Hair': ['short hair', 'dark brown hair', 'slicked back'],
#    'Eyes': ['sharp eyes', 'dark eyes', 'serious expression'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips', 'slightly curved'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Muscle': 'Strong'}}},
#  '无名副手': {'Name': '无名副手',
#   'Gender': 'Male',
#   'Description': '无名副手是一位勤奋而低调的男性，他总是在背后默默支持着前线的工作。他性格温和，待人友善，但在关键时刻却能够展露出坚定的决心。虽然他的名字无人知晓，但他在团队中的作用不可或缺。无名副手擅长处理复杂的事务，常常被视为智慧的象征。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'otouto',
#   'Appearance': {'Hair': ['short hair', 'dark brown hair', 'messy hair'],
#    'Eyes': ['brown eyes', 'sharp gaze'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['slightly angular chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Muscle': 'Weak'}}},
#  '无名负责人': {'Name': '无名负责人',
#   'Gender': 'Male',
#   'Description': '无名负责人是一位沉稳而果断的男性，他在商业调查科中负责重要案件的处理。外表冷峻，极具职业感，给人一种强烈的信任感。他的性格严谨，注重细节，总是保持冷静的思维，即使在压力之下也能迅速做出判断。无名负责人的背景复杂，曾在多个领域工作，积累了丰富的经验和人脉，因此对各种情况都有独到的见解。',
#   'Role': 'male protagonist',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['short hair', 'dark hair', 'spiky hair'],
#    'Eyes': ['sharp eyes', 'dark eyes'],
#    'Skin': ['pale skin'],
#    'Lips': ['thin lips', 'neutral expression'],
#    'Nose': ['straight nose'],
#    'Chin': ['square chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Muscle': 'weak'}}},
#  '王总': {'Name': '王总',
#   'Gender': 'Male',
#   'Description': '王总是一位精明强干的商业领袖，具有强烈的决策能力和领导魅力。他深谙商道，善于把握合作机会，性格沉稳而内敛，时而流露出深邃的智慧。王总的外表平易近人，却又不失威严，让人感受到他的权威与影响力。',
#   'Role': 'male protagonist',
#   'Anime character archetype': 'ouji-sama',
#   'Appearance': {'Hair': ['black_hair', 'short_hair', 'stylish_hair'],
#    'Eyes': ['dark_eyes', 'sharp_eyes'],
#    'Skin': ['light_skin'],
#    'Lips': ['normal_lips'],
#    'Nose': ['normal_nose'],
#    'Chin': ['defined_chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Muscle': 'strong'}}},
#  '商业调查科负责人': {'Name': '马士博',
#   'Gender': 'Male',
#   'Description': '马士博是一位商业调查科的负责人，性格沉稳而冷静，善于分析和判断。他在公司内部备受尊重，常常以敏锐的洞察力和果断的决策赢得同事的信赖。他的外表整洁，注重形象，给人一种精英的感觉，然而在内心深处，他对商业竞争的激烈和复杂有着深深的理解和思考。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'ikemen',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'neat'],
#    'Eyes': ['sharp eyes', 'dark brown eyes', 'serious expression'],
#    'Skin': ['light skin', 'smooth skin'],
#    'Lips': ['thin lips', 'neutral expression'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Muscle': 'Strong'}}},
#  '凯尔副总陈倩': {'Name': '凯尔副总陈倩',
#   'Gender': 'Female',
#   'Description': '陈倩是一位充满自信与魅力的职场女性，她的气质高贵而优雅，仿佛天生就适合在商界中游刃有余。她总是表现出冷静和理智，尽管内心也有自己的情感波动。她对工作一丝不苟，追求完美，常常给人一种强势的印象，但在她的微笑中又透出温柔的一面。她的穿着时尚且具有设计感，能够凸显她的身材与气质。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'ojou-sama',
#   'Appearance': {'Hair': ['long hair', 'black hair', 'straight hair'],
#    'Eyes': ['sharp eyes', 'green eyes'],
#    'Skin': ['pale skin'],
#    'Lips': ['full lips', 'red lips'],
#    'Nose': ['petite nose'],
#    'Chin': ['pointed chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Breast': 'Big'}}},
#  '无名角色': {'Name': '无名角色',
#   'Gender': 'Male',
#   'Description': '无名角色是一位神秘的年轻人，拥有深邃的眼神和敏锐的直觉。他对武学充满热情，虽然不懂高深的技艺，但对武德有着自己独特的理解。他在小镇上显得有些孤独，总是沉浸在自己的思考中，对周围的事物保持着一种淡淡的观察。他的性格内敛而坚定，内心却藏着对力量与勇气的渴望。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'spiky hair'],
#    'Eyes': ['red eyes', 'sharp eyes'],
#    'Skin': ['pale skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['angular chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Muscle': 'Weak'}}},
#  '钟良宽': {'Name': '钟良宽',
#   'Gender': 'Male',
#   'Description': '钟良宽是一位中年男子，身材略显消瘦，脸上布满了岁月的痕迹，显得有些沧桑。他是一个传统而诚实的农民出身，性格憨厚，待人真诚，总是努力支撑着自己几乎倒闭的玩具厂。虽然眼中透着困惑和无奈，但在危机时刻，他依旧能够感受到一丝希望，尤其在面对可能的合作时，眼中闪烁着期待的光芒。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['short hair', 'brown hair', 'messy hair'],
#    'Eyes': ['brown eyes', 'tired eyes'],
#    'Skin': ['light skin', 'weathered skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['slightly hooked nose'],
#    'Chin': ['square chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Muscle': 'weak'}}},
#  '大堂经理': {'Name': '肖雅',
#   'Gender': 'Female',
#   'Description': '肖雅是一位年轻而充满魅力的银行大堂经理，身材玲珑有致，职业装展现出她的优雅与干练。她的笑容甜美，酒窝迷人，给人一种亲切而自信的感觉。虽然她在工作中表现出极高的专业性，但她内心却对生活充满了激情和理想，渴望能在金融行业中有所作为。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'deredere',
#   'Appearance': {'Hair': ['long hair', 'wavy hair', 'brown hair'],
#    'Eyes': ['large eyes', 'green eyes'],
#    'Skin': ['fair skin'],
#    'Lips': ['full lips', 'rosy lips'],
#    'Nose': ['petite nose'],
#    'Chin': ['slender chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Breast': 'Medium'}}},
#  '客户经理': {'Name': '肖雅',
#   'Gender': 'Female',
#   'Description': '肖雅是一位年轻而又充满职业魅力的银行客户经理，性格温和且富有亲和力。她总是面带迷人的微笑，善于与客户沟通，给人一种稳重可靠的感觉。虽然她的工作繁忙，但她总能保持优雅的姿态，给人一种能力出众的印象。她非常注重自己的外在形象，穿着时尚的职业装，展现出她的专业素养。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'female protagonist',
#   'Appearance': {'Hair': ['long hair',
#     'brown hair',
#     'straight hair',
#     'professional hairstyle'],
#    'Eyes': ['brown eyes', 'sparkling eyes'],
#    'Skin': ['fair skin'],
#    'Lips': ['full lips', 'light pink lips'],
#    'Nose': ['petite nose'],
#    'Chin': ['oval chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Breast': 'Medium'}}},
#  '肖雅': {'Name': '肖雅',
#   'Gender': 'Female',
#   'Description': '肖雅是一位年轻的银行大堂经理，外表清秀，性格温柔而细腻。她在工作中始终保持职业的微笑，但内心深处却有着对生活的深刻理解与思考。她不仅在业务上表现出色，还能与客户建立良好的关系，令每位客户感受到温暖与信任。她心中有着对未来的憧憬，希望能在金融行业中取得更大的成就。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'ojou-sama',
#   'Appearance': {'Hair': ['long hair',
#     'straight hair',
#     'brown hair',
#     'hair bun'],
#    'Eyes': ['bright eyes', 'green eyes', 'elegant eyes'],
#    'Skin': ['fair skin'],
#    'Lips': ['full lips', 'rosy lips'],
#    'Nose': ['petite nose'],
#    'Chin': ['oval chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Breast': 'Medium'}}},
#  '其他男生': {'Name': '李明',
#   'Gender': 'Male',
#   'Description': '李明是一名活泼开朗的高中生，个性热情且正义感强。他总是乐于助人，对朋友非常忠诚，尤其在看到同学受到不公对待时，他会毫不犹豫地站出来发声。李明的幽默感很强，常常能用一句玩笑化解尴尬的气氛。尽管他有时显得有些冲动，但他内心充满善良，渴望为身边的人带来快乐。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'genki boy',
#   'Appearance': {'Hair': ['short hair', 'spiky hair', 'dark brown hair'],
#    'Eyes': ['bright eyes', 'large eyes', 'green eyes'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['round chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Muscle': 'weak'}}},
#  '无名女生': {'Name': '无名女生',
#   'Gender': 'Female',
#   'Description': '无名女生是一位内向而敏感的女孩，她总是默默关注着周围的一切，对身边的朋友十分关心，但又不善于表达自己的情感。她在课堂上认真听讲，却常常在课间思考自己的未来。虽然外表平凡，但她的内心充满了梦想与渴望，她希望能找到自己的位置，勇敢地追求自己的理想。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['long hair', 'black hair', 'straight hair'],
#    'Eyes': ['green eyes', 'big eyes'],
#    'Skin': ['pale skin'],
#    'Lips': ['soft lips', 'natural lips'],
#    'Nose': ['small nose'],
#    'Chin': ['pointy chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Breast': 'Medium'}}},
#  '无名男生': {'Name': '无名男生',
#   'Gender': 'Male',
#   'Description': '无名男生是一个看似普通却充满魅力的高中生。他性格外向，善于交际，总是能轻松融入班级的氛围。他在同学中显得特别自信，尤其在与女生的互动中，总能展现出幽默的一面。尽管外表普通，但他在朋友面前流露出的真诚和风趣使他总是成为聚会的中心。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'genki boy',
#   'Appearance': {'Hair': ['short hair', 'spiky hair', 'brown hair'],
#    'Eyes': ['bright eyes', 'hazel eyes'],
#    'Skin': ['light skin', 'smooth skin'],
#    'Lips': ['thin lips', 'smiling lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['pointed chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Muscle': 'weak'}}},
#  '无名同学': {'Name': '无名同学',
#   'Gender': 'Male',
#   'Description': '无名同学是一个普通的大学生，外表平凡却极具观察力。他在班级中并不显眼，但内心对时尚与生活有着自己的理解。虽然外表上他不够自信，但他对朋友们的关心与支持却让他成为了一个值得信赖的人。他常常默默关注身边发生的事情，内心充满了对未来的憧憬与不安。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'genki boy',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'messy hair'],
#    'Eyes': ['brown eyes', 'detailed eyes'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['normal nose'],
#    'Chin': ['pointed chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Muscle': 'Weak'}}},
#  '同学': {'Name': '同学',
#   'Gender': 'Male',
#   'Description': '同学是一位性格开朗、乐于助人的男生，虽然他在校园中并不特别引人注目，但总是能在同学们需要帮助时出现。他擅长社交，热爱运动，常常和朋友们一起打篮球。他有着一颗善良的心，热爱分享，总是愿意倾听他人的烦恼，给予支持和鼓励。',
#   'Role': 'protagonist',
# ...
#   'Role': 'supporting character',
#   'Anime character archetype': 'onesan',
#   'Appearance': {'Hair': ['long hair',
#     'black hair',
#     'straight hair',
#     'hair bun'],
#    'Eyes': ['brown eyes', 'large eyes', 'gentle eyes'],
#    'Skin': ['fair skin'],
#    'Lips': ['soft lips', 'natural lips'],
#    'Nose': ['small nose'],
#    'Chin': ['slight chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Breast': 'Medium'}}},
#  '为首男子': {'Name': '为首男子',
#   'Gender': 'Male',
#   'Description': '为首男子是一个阴险冷酷的角色，身材高大，气质凶狠。他的眼神中透着一种不屑和威胁，仿佛能够看透他人的内心。他总是带着阴冷的笑容，给人一种难以接近的感觉。无论是在行动还是语言上，他都表现出极强的控制欲和支配欲，是一个典型的反派角色。',
#   'Role': 'male antagonist',
#   'Anime character archetype': 'mastermind villain',
#   'Appearance': {'Hair': ['short hair', 'dark hair', 'messy hair'],
#    'Eyes': ['narrow eyes', 'cold eyes', 'sharp gaze'],
#    'Skin': ['pale skin', 'scarred skin'],
#    'Lips': ['thin lips', 'smirking lips'],
#    'Nose': ['sharp nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '化妆护士': {'Name': '化妆护士',
#   'Gender': 'Female',
#   'Description': '化妆护士是一位外表迷人却内心阴险的女性，她的妆容精致，常常给人一种伪装的感觉。她利用她的医术和魅力来操控他人，性格冷酷无情，毫不迟疑地对待她的受害者。她是一名在黑暗中游走的护士，外表优雅，内心却充满了阴暗的欲望。',
#   'Role': 'antagonist',
#   'Anime character archetype': 'femme fatale',
#   'Appearance': {'Hair': ['long hair',
#     'curly hair',
#     'dark hair',
#     'shoulder_length_hair'],
#    'Eyes': ['red eyes', 'sharp eyes'],
#    'Skin': ['pale skin'],
#    'Lips': ['red lips', 'full lips'],
#    'Nose': ['small nose'],
#    'Chin': ['pointed chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Breast': 'Medium'}}},
#  '带头大哥': {'Name': '带头大哥',
#   'Gender': 'Male',
#   'Description': '带头大哥是一个冷酷无情的角色，眼神如刀，给人一种深不可测的压迫感。他是江湖上的老手，经历过无数风波，内心充满了对生存的渴望与对未来的迷茫。在他的眼中，权力与金钱是唯一的追求，但又不断被现实打击，显得格外悲哀。他的外表透露出一种强烈的男性气息，给人以威严和恐惧。',
#   'Role': 'antagonist',
#   'Anime character archetype': 'corrupt leader',
#   'Appearance': {'Hair': ['short hair', 'dark hair', 'slicked back'],
#    'Eyes': ['cold eyes', 'sharp gaze', 'dark sclera'],
#    'Skin': ['tanned skin', 'rough skin'],
#    'Lips': ['thin lips', 'neutral expression'],
#    'Nose': ['prominent nose', 'sharp nose'],
#    'Chin': ['strong chin', 'defined jawline'],
#    'Body': {'Height': 'tall', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '赖三': {'Name': '赖三',
#   'Gender': 'Male',
#   'Description': '赖三是一位身世坎坷的青年，曾在街头混迹多年，性格内敛而坚韧。他心中怀有对未来的渴望，却被现实的无情压迫所困扰。赖三对江河有着深厚的感情，既是仰慕也是依赖。他的外表散发出一股不屈的气质，眼神中常常流露出一丝不安与思索，让人感受到他内心的挣扎与渴望。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'genki boy',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'messy hair'],
#    'Eyes': ['brown eyes', 'determined eyes'],
#    'Skin': ['light skin', 'slightly tanned skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Muscle': 'weak'}}},
#  '女护士': {'Name': '小雪',
#   'Gender': 'Female',
#   'Description': '小雪是一位年轻的女护士，性格直率且坚强。尽管她在工作中时常面临压力，但她始终保持冷静和专业。她对待病人总是非常耐心，然而在面对不公时，她也会毫不犹豫地表达自己的不满。小雪有着一头柔顺的黑长发，常常扎成马尾，显得干练而且活泼，她的眼神中闪烁着聪慧与坚定，时常让人感受到她的坚韧与勇气。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'deredere',
#   'Appearance': {'Hair': ['long_hair', 'black_hair', 'ponytail'],
#    'Eyes': ['green_eyes', 'sharp_eyes'],
#    'Skin': ['fair_skin'],
#    'Lips': ['full_lips', 'pink_lips'],
#    'Nose': ['small_nose'],
#    'Chin': ['pointed_chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Breast': 'Medium'}}},
#  '江河': {'Name': '江河',
#   'Gender': 'Male',
#   'Description': '江河是一位经历丰富的男人，三十五岁，外表看起来粗犷但却隐含着智慧。他曾是街头混混，后成为武馆的学徒，身上带着不屈的斗志和沉重的生活经历。江河内心深处渴望着更好的生活，对身边的兄弟们充满关心，时常为他们的未来感到担忧。他的眼神中透出一丝沧桑，仿佛经历了无数风雨，但仍然保持着对理想的追求。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'dark hero',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'messy hair'],
#    'Eyes': ['sharp eyes', 'dark brown eyes'],
#    'Skin': ['tanned skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['strong nose'],
#    'Chin': ['square chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '伪娘': {'Name': '伪娘',
#   'Gender': 'Male',
#   'Description': '伪娘是一位具有独特魅力的男性角色，外表柔美，常常穿着女性化的服装。他的性格内向而敏感，擅长倾听和理解他人的感受。在这个充满挑战和压力的环境中，他用自己的温柔和同情心来安慰和支持身边的朋友。尽管外表看似脆弱，但内心却坚定不移，渴望为身边的人带来安宁。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'genki boy',
#   'Appearance': {'Hair': ['long_hair', 'wavy_hair', 'pink_hair'],
#    'Eyes': ['big_eyes', 'purple_eyes'],
#    'Skin': ['fair_skin'],
#    'Lips': ['full_lips', 'pink_lips'],
#    'Nose': ['small_nose'],
#    'Chin': ['soft_chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Breast': 'Medium'}}},
#  '手下': {'Name': '手下',
#   'Gender': 'Male',
#   'Description': '手下是一名忠诚而果断的年轻男子，虽然外表看似普通，但他在关键时刻总能展现出令人意想不到的能力。他对江河极为忠心，曾多次为他出谋划策。然而，内心深处他也承受着巨大的压力，面对忠诚与背叛的选择，他的内心斗争使他更加复杂。手下总是保持冷静，眼神透出一丝坚定与倔强。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['short hair', 'dark hair', 'spiky hair'],
#    'Eyes': ['blue eyes', 'sharp eyes'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['square chin'],
#    'Body': {'Height': 'medium', 'Build': 'athletic', 'Muscle': 'Strong'}}},
#  '无名堂口话事人': {'Name': '无名堂口话事人',
#   'Gender': 'Male',
#   'Description': '无名堂口话事人是一位神秘而沉稳的男性，身处江城地下世界，拥有强大的影响力和深厚的谋略。他总是面带冷静的微笑，目光如炬，似乎能够洞察人心。平日里，他在众人面前显得从容不迫，但内心深处却充满了对权力斗争的敏感和警惕。他是一个能够驾驭复杂局势的人物，善于倾听和分析，常常在关键时刻提出决定性的意见。',
#   'Role': 'male protagonist',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'slicked back'],
#    'Eyes': ['sharp eyes', 'dark eyes'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips', 'neutral expression'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'athletic', 'Muscle': 'Strong'}}},
#  '无名手下': {'Name': '无名手下',
#   'Gender': 'Male',
#   'Description': '无名手下是一位忠诚而严肃的角色，他身材高大，肌肉结实，给人一种强烈的威慑感。他总是认真地履行自己的职责，冷静而果断，散发出一种不容忽视的气场。虽然他没有华丽的外表，但他的存在让人感到安心。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'yankee',
#   'Appearance': {'Hair': ['bald', 'shaved_head'],
#    'Eyes': ['narrow_eyes', 'serious_eyes'],
#    'Skin': ['tanned_skin'],
#    'Lips': ['thin_lips'],
#    'Nose': ['broad_nose'],
#    'Chin': ['square_chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '无名堂主1': {'Name': '无名堂主1',
#   'Gender': 'Male',
#   'Description': '无名堂主1是一位神秘而强大的角色，常常在黑暗的街道中游走。他身材高大，面容冷峻，给人一种威严而不容侵犯的感觉。他在江城的黑道中默默积累着自己的势力，虽然是新晋堂主，却有着与生俱来的气场和领导能力。无名堂主1心思深沉，善于观察周围的一切，时常保持沉默，给人一种不可捉摸的神秘感。',
#   'Role': 'male protagonist',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['short hair', 'dark hair', 'spiky hair'],
#    'Eyes': ['narrow eyes', 'dark eyes', 'piercing gaze'],
#    'Skin': ['pale skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['sharp nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Muscle': 'Strong'}}},
#  '无名堂主2': {'Name': '无名堂主2',
#   'Gender': 'Male',
#   'Description': '无名堂主2是一位神秘而沉稳的男性，他在黑道中行事低调，默默积累实力。尽管外表看似普通，但他内心深处却蕴藏着丰富的智慧和战略眼光。他为人忠诚，重视兄弟情谊，能在关键时刻做出果断的决策。无名堂主2在聚义堂中扮演着重要的角色，虽然名声不显，但他的影响力不可小觑。',
#   'Role': 'supporting character',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['short hair', 'dark hair', 'spiky hair'],
#    'Eyes': ['sharp eyes', 'dark eyes'],
#    'Skin': ['tanned skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular'}}},
#  '无名堂主3': {'Name': '无名堂主3',
#   'Gender': 'Male',
#   'Description': '无名堂主3是一位年轻而充满活力的男性，身材修长，面容英俊。他在社团中虽然默默无闻，但却拥有敏锐的洞察力和极强的适应能力。他的性格乐观，待人真诚，常常是大家的调节者。尽管外表冷静，内心却渴望被认可，希望能在德爷的指导下展现自己的能力。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'genki boy',
#   'Appearance': {'Hair': ['short_hair', 'spiky_hair', 'black_hair'],
#    'Eyes': ['bright_eyes', 'blue_eyes'],
#    'Skin': ['light_skin'],
#    'Lips': ['thin_lips'],
#    'Nose': ['straight_nose'],
#    'Chin': ['pointed_chin'],
#    'Body': {'Height': 'medium', 'Build': 'slender', 'Muscle': 'weak'}}},
#  '无名堂主4': {'Name': '无名堂主4',
#   'Gender': 'Male',
#   'Description': '无名堂主4是一位神秘而坚定的男性角色，他在江城的黑道中拥有独特的地位。虽然他名不见经传，但在堂口内外都颇具威望。他的性格沉稳而睿智，善于观察和分析周围的情况，总是以冷静的态度处理各种复杂的局面。他身上的神秘气息让人难以捉摸，但他内心却充满了对兄弟情义的忠诚和对权力的渴望。',
#   'Role': 'male protagonist',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['short hair', 'dark hair', 'spiky hair'],
#    'Eyes': ['sharp eyes', 'dark eyes'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '无名堂主5': {'Name': '无名堂主5',
#   'Gender': 'Male',
#   'Description': '无名堂主5是一位神秘而沉稳的男性角色，身为黑道中的一员，他总是保持着冷静与睿智。他身材高大，给人一种威严的感觉，虽然平时话语不多，但他的一举一动都透露出强大的气场。无名堂主5对自己的职责相当认真，尽管身处危险的环境中，但他总是能够保持头脑清醒，善于观察周围的动态。他的身世成谜，似乎有着不为人知的过往。',
#   'Role': 'male protagonist',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['short_hair', 'black_hair', 'spiky_hair'],
#    'Eyes': ['narrow_eyes', 'dark_eyes'],
#    'Skin': ['light_skin'],
#    'Lips': ['thin_lips'],
#    'Nose': ['straight_nose'],
#    'Chin': ['chiseled_chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular'}}},
#  '无名堂主6': {'Name': '无名堂主6',
#   'Gender': 'Male',
#   'Description': '无名堂主6是一名神秘而略显阴郁的角色，他在江城的黑道中默默无闻，外表冷漠却内心深藏着丰富的情感与野心。他身处权力的游戏中，时常思考着如何在这个残酷的世界中生存并提升自己的地位。虽然名声不显，但他拥有超凡的智慧和敏锐的洞察力，能在复杂的局势中寻找到自己的立足之地。',
#   'Role': 'male protagonist',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['dark hair', 'short hair', 'messy hair'],
#    'Eyes': ['sharp eyes', 'green eyes'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Muscle': 'Strong'}}},
#  '无名堂主7': {'Name': '无名堂主7',
#   'Gender': 'Male',
#   'Description': '无名堂主7是一位神秘的角色，肆无忌惮地在黑道中游刃有余。他有着迷人的外表和不羁的气质，虽身处危险的境地，却总能保持冷静和自信。他的背影充满魅力，似乎每一步都隐藏着深不可测的故事。他在江城的黑道中积累了不少人脉，性格果断，善于处理复杂局面，但内心深处却对权力的渴望让他有些不安。',
#   'Role': 'male antagonist',
#   'Anime character archetype': 'dark hero',
#   'Appearance': {'Hair': ['short hair', 'spiky hair', 'black hair'],
#    'Eyes': ['sharp eyes', 'dark eyes', 'intense gaze'],
#    'Skin': ['tanned skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['sharp chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '无名堂主8': {'Name': '无名堂主8',
#   'Gender': 'Male',
#   'Description': '无名堂主8是一位外表冷峻的男性，在江城的黑道中声名不显，但内心深藏着对权力的渴望。他性格沉稳，善于隐藏自己的情感，表面上冷酷无情，实则内心复杂。他曾经历过无数挑战，逐渐成长为一名精明的领导者，能够在逆境中保持冷静。',
#   'Role': 'antagonist',
#   'Anime character archetype': 'dark hero',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'messy hair'],
#    'Eyes': ['sharp eyes', 'dark eyes', 'narrow eyes'],
#    'Skin': ['pale skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '秦霜的三哥': {'Name': '秦霜的三哥',
#   'Gender': 'Male',
#   'Description': '秦霜的三哥是一位身材高大、气宇轩昂的年轻男子，性格坚定而富有责任感。他对家族非常忠诚，尤其在得知史金与秦霜的事后，展现出强烈的保护欲和愤怒。他的表情通常是严肃而冷静，但在愤怒时会露出一丝冲动的火焰。他的外表散发着一种威严的气场，让人不敢轻视。',
#   'Role': 'male protagonist',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['short hair', 'dark hair', 'straight hair'],
#    'Eyes': ['sharp eyes', 'dark eyes'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular'}}},
#  '钟老板': {'Name': '钟老板',
#   'Gender': 'Male',
#   'Description': '钟老板是一位精明能干的企业家，拥有丰富的商业头脑和技术知识。他对创新和进步充满热情，总是寻找新的机会来推动自己的工厂发展。他的外表严肃而坚定，常常给人一种威严的感觉，但内心深处又有着对员工的关怀和对事业的热爱。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'ikemen',
#   'Appearance': {'Hair': ['black_hair', 'short_hair', 'styled_hair'],
#    'Eyes': ['sharp_eyes', 'green_eyes'],
#    'Skin': ['light_skin'],
#    'Lips': ['thin_lips'],
#    'Nose': ['straight_nose'],
#    'Chin': ['strong_chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular'}}},
#  '牛人': {'Name': '牛人',
#   'Gender': 'Male',
#   'Description': '牛人是一位卓越的商界领袖，他凭借着前世的智慧和经验，不断创造着惊人的财富。他外表冷静而自信，给人一种不可阻挡的气场。他的眼神中透露出深邃的智慧和坚定的决心，时常能一眼识破他人的动机和情感。牛人不仅仅是一位商人，更是一位智慧的引导者，他在复杂的商业环境中游刃有余，永远在关键时刻做出正确的选择。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'ikemen',
#   'Appearance': {'Hair': ['black hair', 'short hair', 'spiky hair'],
#    'Eyes': ['sharp eyes', 'green eyes'],
#    'Skin': ['light skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Muscle': 'strong'}}},
#  '秦家人': {'Name': '秦家人',
#   'Gender': 'Male',
#   'Description': '秦家人是一个精明而狡诈的商人，外表总是给人一种冷酷无情的感觉。他充满了贪婪和算计，目光总是闪烁着对财富和权利的渴望。他在社交场合中表现得极为得体，总是面带微笑，但内心里却暗流涌动，随时准备利用他人来达到自己的目的。',
#   'Role': 'antagonist',
#   'Anime character archetype': 'mastermind villain',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'greasy hair'],
#    'Eyes': ['narrow eyes', 'golden eyes', 'sharp gaze'],
#    'Skin': ['pale skin', 'smooth skin'],
#    'Lips': ['thin lips', 'smirking lips'],
#    'Nose': ['straight nose'],
#    'Chin': ['pointed chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Muscle': 'Weak'}}},
#  '罗斯家族': {'Name': '罗斯家族',
#   'Gender': 'Male',
#   'Description': '罗斯家族是一群富有权势的金融世家，以狡诈和冷酷著称。他们精通操控金钱与权力，始终在黑暗中潜行，谋划着如何通过阴暗手段获取更多财富。家族成员通常身着高档西装，面带冷酷的笑容，目光如鹰，透着无情与智慧。家族的每位成员都对自己的目标充满执着，尤其是在策划史金的刺杀计划时，他们展现出了无与伦比的狡诈与果断。',
#   'Role': 'antagonist',
#   'Anime character archetype': 'mastermind villain',
#   'Appearance': {'Hair': ['short hair', 'black hair', 'slicked back'],
#    'Eyes': ['sharp eyes', 'golden eyes', 'piercing gaze'],
#    'Skin': ['pale skin'],
#    'Lips': ['thin lips', 'smirking'],
#    'Nose': ['aquiline nose'],
#    'Chin': ['pointed chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Muscle': 'Weak'}}},
#  '异人组': {'Name': '异人组',
#   'Gender': 'Male',
#   'Description': '异人组是一支由各种能力者组成的高科技团队，神秘而强大。他们被赋予了保护华国的使命，拥有各自独特的能力和背景。团队成员间的默契配合令他们在危机中能够迅速作出反应，完成任务。异人组的外表风格多样，既有冷酷的战士，也有聪慧的战术家，展现出他们的多元化和团结。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'male protagonist',
#   'Appearance': {'Hair': ['black_hair', 'blue_hair', 'white_hair', 'red_hair'],
#    'Eyes': ['sharp_eyes', 'glowing_eyes', 'heterochromia'],
#    'Skin': ['light_skin', 'tan_skin'],
#    'Lips': ['thin_lips', 'full_lips'],
#    'Nose': ['straight_nose', 'sharp_nose'],
#    'Chin': ['square_chin', 'pointed_chin'],
#    'Body': {'Height': 'tall', 'Build': 'muscular', 'Muscle': 'Strong'}}},
#  '科技巨头': {'Name': '科技巨头',
#   'Gender': 'Male',
#   'Description': '科技巨头是一位充满魅力的商业领袖，他拥有超凡的智慧和非凡的创造力，能够在科技领域引领潮流。他身穿时尚而前卫的服装，始终保持着自信的微笑和锐利的目光，仿佛能看穿一切。他的背景是一个天才少年，因对科技的热爱而在商业界崭露头角，成为了无数人追随的榜样。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'ikemen',
#   'Appearance': {'Hair': ['short hair', 'spiky hair', 'silver hair'],
#    'Eyes': ['sharp eyes', 'blue eyes', 'glasses'],
#    'Skin': ['light skin', 'smooth skin'],
#    'Lips': ['thin lips', 'confident smile'],
#    'Nose': ['straight nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Muscle': 'strong'}}},
#  '异人组织': {'Name': '异人组织',
#   'Gender': 'Male',
#   'Description': '异人组织是一个神秘而强大的团体，代表着超越人类的智慧与力量。他们的成员个个都拥有特殊能力，外表各异，却都散发着非凡的气息。组织的领导者冷静而果断，智谋过人，具有卓越的领导才能。他们不仅具备强大的战斗力，还掌握着先进的科技，致力于守护人类文明与抵御外来威胁。',
#   'Role': 'protagonist',
#   'Anime character archetype': 'kuudere',
#   'Appearance': {'Hair': ['black hair', 'silver hair', 'blue hair'],
#    'Eyes': ['piercing gaze', 'glowing eyes', 'sharp eyes'],
#    'Skin': ['pale skin', 'dark skin'],
#    'Lips': ['thin lips', 'normal lips'],
#    'Nose': ['sharp nose'],
#    'Chin': ['strong chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Muscle': 'Strong'}}},
#  '国际组织': {'Name': '国际组织',
#   'Gender': 'Male',
#   'Description': '国际组织是一位神秘而强大的角色，身处阴影之中，掌控着庞大的权力和资源。他的外表冷酷、果断，给人一种深不可测的感觉。性格阴险且聪明，善于操控他人，利用各种手段达到自己的目的。尽管外表冷漠，但内心深处却隐藏着对权力的渴望和对人性的深刻理解。',
#   'Role': 'antagonist',
#   'Anime character archetype': 'mastermind villain',
#   'Appearance': {'Hair': ['black hair', 'short hair', 'slicked-back'],
#    'Eyes': ['red eyes', 'sharp gaze'],
#    'Skin': ['pale skin'],
#    'Lips': ['thin lips'],
#    'Nose': ['sharp nose'],
#    'Chin': ['angular chin'],
#    'Body': {'Height': 'tall', 'Build': 'slender', 'Muscle': 'strong'}}}}
